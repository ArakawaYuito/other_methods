# %%
import xgboost as xgb
import warnings
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score
from sklearn.exceptions import UndefinedMetricWarning
from sklearn.model_selection import KFold
import pandas as pd
import os
import numpy as np
import support 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def under_sampling(x):
    import warnings
    import pandas as pd
    import os
    warnings.simplefilter('ignore', pd.core.common.SettingWithCopyWarning)
    df = x
    x_majority=df.loc[df.iloc[:,-1]==0]
    x_minority=df.loc[df.iloc[:,-1]==1]
    from sklearn.cluster import KMeans
    km = KMeans(random_state=1, n_clusters=10)
    km.fit(x_majority.iloc[:, :-1])
    x_majority['Cluster'] = km.predict(x_majority.iloc[:, :-1])
    ratio = x_majority['Cluster'].value_counts() / x_majority.shape[0]
    n_sample_ary = (ratio * x_minority.shape[0]).sort_index().astype('int64')
    df_Xs=[]
    for i, n_sample in enumerate(n_sample_ary):
        #重複を許すか許さないかで変わるのか？
        df_Xs.append(x_majority[x_majority['Cluster']==i].sample(n=n_sample, replace=True))

    df_Xs.append(x_minority)
    x=pd.concat(df_Xs, sort=True)
    x=x.drop('Cluster', axis=1)
    
    return x

def calc_avg(x, y):
    import pandas as pd
    import os
    df_x=pd.DataFrame(x)
    df_y=pd.DataFrame(y)
    df_x_raw=df_x[(df_x.shape[1]-1)/2]
    raw_df=pd.concat([df_x_raw, df_y], axis=1)
    raw_df.columns=range(raw_df.shape[1])
    df_ex=raw_df.loc[raw_df[1]==0]
    N=len(df_ex)
    Leq=10*np.log10(np.sum(np.power(10, df_ex[0]/10)))-10*np.log10(N)
    return Leq

def calc_avg2(x, y):
    import pandas as pd
    import os
    df_x=pd.DataFrame(x)
    df_y=pd.DataFrame(y)
    df_x_raw=df_x[(df_x.shape[1]-1)/2]
    raw_df=pd.concat([df_x_raw, df_y], axis=1)
    raw_df.columns=range(raw_df.shape[1])
    df_ex=raw_df
    N=len(df_ex)
    Leq=10*np.log10(np.sum(np.power(10, df_ex[0]/10)))-10*np.log10(N)
    return Leq

df = pd.read_csv( os.path.join('dataset', 'learning_data_431975.csv'), header=None  )
x = df[ df.columns[ :-1 ] ]
y=  df[ df.columns[ -1 ] ]
kf = KFold( n_splits=3, random_state=1, shuffle=True )
pr=[]
re=[]
f1 = []
ac = []
y_Leq=[]
pred_Leq=[]
no_Leq=[]
n = []

for train_index, test_index in kf.split( x ):
    x_train, x_test = x.loc[train_index, :].values, x.loc[test_index, :].values
    y_train, y_test = y.loc[train_index].values, y.loc[test_index].values

    # 学習データだけダウンサンプリング
    y_data=y_train[:, np.newaxis]
    data=np.concatenate([x_train, y_data], 1)
    train_df=pd.DataFrame(data)
    train_us=under_sampling(train_df)
    index = train_us.index.tolist()
    x_train=x_train[index]
    y_train=y_train[index]
    
    # アーリーストッピング(学習の打ち切り)するために、学習中のバリデーション用の検証データを作成
    # (学習データをさらに ’学習データ’と ’検証データ’ に分割)
    x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=True)
    
    # XGBoost用にデータを加工
    dtrain = xgb.DMatrix(x_train, label=y_train)
    dvalid = xgb.DMatrix(x_valid, label=y_valid) # 学習中のバリデーション用の検証データ
    dtest  = xgb.DMatrix(x_test, label=y_test)
    
    params = {'objective':'binary:logistic',
              'eval_metric': 'logloss', # 学習中のバリデーションに使う評価指標
              'random_state':1,
              'eta':0.01,  
              'max_depth':4,
              'lambda':10,
              'alpha':0
             
             }
    num_round = 1000
    watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
    evals_result={}
    model = xgb.train(params, dtrain, num_round, verbose_eval=10, 
                      evals=watchlist, evals_result=evals_result, early_stopping_rounds=5)
    
    # 検証結果のうち最も結果が良かった木の数で予測
    y_pred_proba = model.predict(dtest,  ntree_limit=model.best_ntree_limit)
    z = np.where(y_pred_proba > 0.5, 1, 0)

    pr.append( precision_score( y_test, z ) )
    re.append( recall_score( y_test, z) )
    f1.append( f1_score( y_test, z ) )
    ac.append( accuracy_score( y_test, z ) )
    n.append( len( x_test ) / len( x ) )

    #等価騒音レベル計算
    no_Leq.append(calc_avg2(x_test, y_test))
    y_Leq.append(calc_avg(x_test, y_test))
    pred_Leq.append(calc_avg(x_test, z))
    
    # 学習の課程を折れ線グラフとしてプロットする
    train_metric = evals_result['train']['logloss']
    plt.plot(train_metric, label='train logloss')
    eval_metric = evals_result['valid']['logloss']
    plt.plot(eval_metric, label='valid logloss')
    plt.grid()
    plt.legend()
    plt.xlabel('rounds')
    plt.ylabel('logloss')
    plt.show()

    
print( 'CV Score:' )
print( '  Precision Score = %f'%( np.average( pr, weights=n ) ) )
print( '  Recall Score = %f'%( np.average( re, weights=n ) ) )
print( '  F1 Score = %f'%( np.average( f1, weights=n ) ) )
print( '  Accuracy Score = %f'%( np.average( ac, weights=n ) ) )
print( '  no_Leq = %f'%( np.average( no_Leq, weights=n ) ) )
print( '  y_Leq = %f'%( np.average( y_Leq, weights=n ) ) )
print( '  pred_Leq = %f'%( np.average( pred_Leq, weights=n ) ) )
# Out:
# [0]	train-logloss:0.69147	valid-logloss:0.69150
# [10]	train-logloss:0.67636	valid-logloss:0.67624
# [20]	train-logloss:0.66370	valid-logloss:0.66330
# [30]	train-logloss:0.65276	valid-logloss:0.65209
# [40]	train-logloss:0.64323	valid-logloss:0.64256
# [50]	train-logloss:0.63508	valid-logloss:0.63408
# [60]	train-logloss:0.62783	valid-logloss:0.62635
# [70]	train-logloss:0.62140	valid-logloss:0.61953
# [80]	train-logloss:0.61560	valid-logloss:0.61343
# [90]	train-logloss:0.61049	valid-logloss:0.60807
# [100]	train-logloss:0.60588	valid-logloss:0.60316
# [110]	train-logloss:0.60176	valid-logloss:0.59881
# [120]	train-logloss:0.59817	valid-logloss:0.59503
# [130]	train-logloss:0.59499	valid-logloss:0.59169
# [140]	train-logloss:0.59206	valid-logloss:0.58878
# [150]	train-logloss:0.58912	valid-logloss:0.58601
# [160]	train-logloss:0.58625	valid-logloss:0.58323
# [170]	train-logloss:0.58367	valid-logloss:0.58078
# [180]	train-logloss:0.58135	valid-logloss:0.57866
# [190]	train-logloss:0.57923	valid-logloss:0.57672
# [200]	train-logloss:0.57742	valid-logloss:0.57493
# [210]	train-logloss:0.57566	valid-logloss:0.57339
# [220]	train-logloss:0.57393	valid-logloss:0.57207
# [230]	train-logloss:0.57224	valid-logloss:0.57076
# [240]	train-logloss:0.57077	valid-logloss:0.56965
# [250]	train-logloss:0.56925	valid-logloss:0.56844
# [260]	train-logloss:0.56792	valid-logloss:0.56744
