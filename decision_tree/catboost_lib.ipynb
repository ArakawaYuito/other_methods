# %%
from catboost import CatBoost
from catboost import Pool
import warnings
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score
from sklearn.exceptions import UndefinedMetricWarning
from sklearn.model_selection import KFold
import pandas as pd
import os
import numpy as np
import support 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def under_sampling(x):
    import warnings
    import pandas as pd
    import os
    warnings.simplefilter('ignore', pd.core.common.SettingWithCopyWarning)
    df = x
    x_majority=df.loc[df.iloc[:,-1]==0]
    x_minority=df.loc[df.iloc[:,-1]==1]
    from sklearn.cluster import KMeans
    km = KMeans(random_state=1, n_clusters=10)
    km.fit(x_majority.iloc[:, :-1])
    x_majority['Cluster'] = km.predict(x_majority.iloc[:, :-1])
    ratio = x_majority['Cluster'].value_counts() / x_majority.shape[0]
    n_sample_ary = (ratio * x_minority.shape[0]).sort_index().astype('int64')
    df_Xs=[]
    for i, n_sample in enumerate(n_sample_ary):
        #重複を許すか許さないかで変わるのか？
        df_Xs.append(x_majority[x_majority['Cluster']==i].sample(n=n_sample, replace=True))

    df_Xs.append(x_minority)
    x=pd.concat(df_Xs, sort=True)
    x=x.drop('Cluster', axis=1)
    
    return x

def calc_avg(x, y):
    import pandas as pd
    import os
    df_x=pd.DataFrame(x)
    df_y=pd.DataFrame(y)
    df_x_raw=df_x[(df_x.shape[1]-1)/2]
    raw_df=pd.concat([df_x_raw, df_y], axis=1)
    raw_df.columns=range(raw_df.shape[1])
    df_ex=raw_df.loc[raw_df[1]==0]
    N=len(df_ex)
    Leq=10*np.log10(np.sum(np.power(10, df_ex[0]/10)))-10*np.log10(N)
    return Leq

def calc_avg2(x, y):
    import pandas as pd
    import os
    df_x=pd.DataFrame(x)
    df_y=pd.DataFrame(y)
    df_x_raw=df_x[(df_x.shape[1]-1)/2]
    raw_df=pd.concat([df_x_raw, df_y], axis=1)
    raw_df.columns=range(raw_df.shape[1])
    df_ex=raw_df
    N=len(df_ex)
    Leq=10*np.log10(np.sum(np.power(10, df_ex[0]/10)))-10*np.log10(N)
    return Leq

df = pd.read_csv( os.path.join('dataset', 'learning_data_431975.csv'), header=None  )
x = df[ df.columns[ :-1 ] ]
y=  df[ df.columns[ -1 ] ]
kf = KFold( n_splits=3, random_state=1, shuffle=True )
pr=[]
re=[]
f1 = []
ac = []
y_Leq=[]
pred_Leq=[]
no_Leq=[]
n = []

for train_index, test_index in kf.split( x ):
    x_train, x_test = x.loc[train_index, :].values, x.loc[test_index, :].values
    y_train, y_test = y.loc[train_index].values, y.loc[test_index].values

    # 学習データだけダウンサンプリング
    y_data=y_train[:, np.newaxis]
    data=np.concatenate([x_train, y_data], 1)
    train_df=pd.DataFrame(data)
    train_us=under_sampling(train_df)
    index = train_us.index.tolist()
    x_train=x_train[index]
    y_train=y_train[index]
    
    # アーリーストッピング(学習の打ち切り)するために、学習中のバリデーション用の検証データを作成
    # (学習データをさらに ’学習データ’と ’検証データ’ に分割)
    x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=True)
    
    # CatBoost用にデータを加工
    dtrain = Pool(x_train, label=y_train)
    dvalid = Pool(x_valid, label=y_valid) # 学習中のバリデーション用の検証データ
    
    params = {
        'loss_function': 'Logloss',
        'num_boost_round': 1000,
        # 検証用データの損失が既定ラウンド数減らなかったら学習を打ち切る
        'early_stopping_rounds': 10,
        'learning_rate':0.01,
             }
    
    model = CatBoost(params)
    model.fit(dtrain, eval_set=[dvalid], use_best_model=True, verbose_eval=10)
    
    y_pred = model.predict(x_test, prediction_type='Probability')
    y_pred = np.argmax(y_pred, axis=1)
    z = np.where(y_pred > 0.5, 1, 0)

    pr.append( precision_score( y_test, z ) )
    re.append( recall_score( y_test, z) )
    f1.append( f1_score( y_test, z ) )
    ac.append( accuracy_score( y_test, z ) )
    n.append( len( x_test ) / len( x ) )

    #等価騒音レベル計算
    no_Leq.append(calc_avg2(x_test, y_test))
    y_Leq.append(calc_avg(x_test, y_test))
    pred_Leq.append(calc_avg(x_test, z))
   
    # メトリックの推移を取得する
    history = model.get_evals_result()

    # グラフにプロットする
    train_metric = history['learn']['Logloss']
    plt.plot(train_metric, label='train metric')
    eval_metric = history['validation']['Logloss']
    plt.plot(eval_metric, label='eval metric')
    plt.legend()
    plt.grid()
    plt.xlabel('rounds')
    plt.ylabel('logloss')
    plt.show()    
    
print( 'CV Score:' )
print( '  Precision Score = %f'%( np.average( pr, weights=n ) ) )
print( '  Recall Score = %f'%( np.average( re, weights=n ) ) )
print( '  F1 Score = %f'%( np.average( f1, weights=n ) ) )
print( '  Accuracy Score = %f'%( np.average( ac, weights=n ) ) )
print( '  no_Leq = %f'%( np.average( no_Leq, weights=n ) ) )
print( '  y_Leq = %f'%( np.average( y_Leq, weights=n ) ) )
print( '  pred_Leq = %f'%( np.average( pred_Leq, weights=n ) ) )
# Out:
# 0:	learn: 0.6912073	test: 0.6912658	best: 0.6912658 (0)	total: 4.7ms	remaining: 4.69s
# 10:	learn: 0.6734584	test: 0.6738750	best: 0.6738750 (10)	total: 23.2ms	remaining: 2.08s
# 20:	learn: 0.6586626	test: 0.6594593	best: 0.6594593 (20)	total: 41.2ms	remaining: 1.92s
# 30:	learn: 0.6461894	test: 0.6472557	best: 0.6472557 (30)	total: 60.6ms	remaining: 1.89s
# 40:	learn: 0.6364274	test: 0.6375408	best: 0.6375408 (40)	total: 79ms	remaining: 1.85s
# 50:	learn: 0.6274479	test: 0.6288474	best: 0.6288474 (50)	total: 97.8ms	remaining: 1.82s
# 60:	learn: 0.6191037	test: 0.6211632	best: 0.6211632 (60)	total: 116ms	remaining: 1.79s
# 70:	learn: 0.6124333	test: 0.6149159	best: 0.6149159 (70)	total: 134ms	remaining: 1.75s
# 80:	learn: 0.6065462	test: 0.6096236	best: 0.6096236 (80)	total: 153ms	remaining: 1.74s
# 90:	learn: 0.6012817	test: 0.6050095	best: 0.6050095 (90)	total: 172ms	remaining: 1.72s
# 100:	learn: 0.5963778	test: 0.6009336	best: 0.6009336 (100)	total: 191ms	remaining: 1.7s
# 110:	learn: 0.5924049	test: 0.5972995	best: 0.5972995 (110)	total: 209ms	remaining: 1.68s
# 120:	learn: 0.5888157	test: 0.5943677	best: 0.5943677 (120)	total: 228ms	remaining: 1.66s
# 130:	learn: 0.5856186	test: 0.5916263	best: 0.5916263 (130)	total: 246ms	remaining: 1.63s
# 140:	learn: 0.5827359	test: 0.5891737	best: 0.5891737 (140)	total: 265ms	remaining: 1.61s
# 150:	learn: 0.5799617	test: 0.5867967	best: 0.5867967 (150)	total: 284ms	remaining: 1.59s
# 160:	learn: 0.5775496	test: 0.5845824	best: 0.5845824 (160)	total: 302ms	remaining: 1.57s
# 170:	learn: 0.5748927	test: 0.5823428	best: 0.5823428 (170)	total: 320ms	remaining: 1.55s
# 180:	learn: 0.5729396	test: 0.5806885	best: 0.5806885 (180)	total: 338ms	remaining: 1.53s
# 190:	learn: 0.5710406	test: 0.5790332	best: 0.5790332 (190)	total: 357ms	remaining: 1.51s
# 200:	learn: 0.5691708	test: 0.5774197	best: 0.5774197 (200)	total: 375ms	remaining: 1.49s
# 210:	learn: 0.5673648	test: 0.5758797	best: 0.5758797 (210)	total: 393ms	remaining: 1.47s
# 220:	learn: 0.5654332	test: 0.5745144	best: 0.5745144 (220)	total: 413ms	remaining: 1.46s
# 230:	learn: 0.5636150	test: 0.5733599	best: 0.5733599 (230)	total: 431ms	remaining: 1.44s
# 240:	learn: 0.5622350	test: 0.5725203	best: 0.5725203 (240)	total: 450ms	remaining: 1.42s
# 250:	learn: 0.5602048	test: 0.5711596	best: 0.5711596 (250)	total: 469ms	remaining: 1.4s
# 260:	learn: 0.5586622	test: 0.5701368	best: 0.5701368 (260)	total: 487ms	remaining: 1.38s
# 270:	learn: 0.5570096	test: 0.5690567	best: 0.5690567 (270)	total: 506ms	remaining: 1.36s
# 280:	learn: 0.5555787	test: 0.5678378	best: 0.5678378 (280)	total: 524ms	remaining: 1.34s
# 290:	learn: 0.5541222	test: 0.5669569	best: 0.5669569 (290)	total: 543ms	remaining: 1.32s
# 300:	learn: 0.5526614	test: 0.5659606	best: 0.5659606 (300)	total: 561ms	remaining: 1.3s
# 310:	learn: 0.5511043	test: 0.5650283	best: 0.5650283 (310)	total: 580ms	remaining: 1.28s
# 320:	learn: 0.5499005	test: 0.5641230	best: 0.5641230 (320)	total: 599ms	remaining: 1.27s
# 330:	learn: 0.5486707	test: 0.5632174	best: 0.5632174 (330)	total: 618ms	remaining: 1.25s
# 340:	learn: 0.5471692	test: 0.5621591	best: 0.5621591 (340)	total: 636ms	remaining: 1.23s
# 350:	learn: 0.5457777	test: 0.5610145	best: 0.5610145 (350)	total: 655ms	remaining: 1.21s
# 360:	learn: 0.5446908	test: 0.5603691	best: 0.5603691 (360)	total: 673ms	remaining: 1.19s
# 370:	learn: 0.5434882	test: 0.5596583	best: 0.5596503 (369)	total: 692ms	remaining: 1.17s
# 380:	learn: 0.5423317	test: 0.5590570	best: 0.5590570 (380)	total: 711ms	remaining: 1.15s
# 390:	learn: 0.5410720	test: 0.5583250	best: 0.5583250 (390)	total: 729ms	remaining: 1.14s
# 400:	learn: 0.5399029	test: 0.5575595	best: 0.5575595 (400)	total: 748ms	remaining: 1.12s
# 410:	learn: 0.5388253	test: 0.5568650	best: 0.5568650 (410)	total: 766ms	remaining: 1.1s
# 420:	learn: 0.5376401	test: 0.5561070	best: 0.5561070 (420)	total: 784ms	remaining: 1.08s
# 430:	learn: 0.5365392	test: 0.5555289	best: 0.5555289 (430)	total: 803ms	remaining: 1.06s
# 440:	learn: 0.5353600	test: 0.5547272	best: 0.5547272 (440)	total: 822ms	remaining: 1.04s
# 450:	learn: 0.5341544	test: 0.5540196	best: 0.5540196 (450)	total: 840ms	remaining: 1.02s
# 460:	learn: 0.5330228	test: 0.5531351	best: 0.5531351 (460)	total: 859ms	remaining: 1s
# 470:	learn: 0.5321308	test: 0.5524864	best: 0.5524864 (470)	total: 877ms	remaining: 985ms
# 480:	learn: 0.5310032	test: 0.5519399	best: 0.5519399 (480)	total: 897ms	remaining: 967ms
# 490:	learn: 0.5300991	test: 0.5513083	best: 0.5513083 (490)	total: 915ms	remaining: 949ms
# 500:	learn: 0.5290646	test: 0.5507484	best: 0.5507484 (500)	total: 934ms	remaining: 930ms
# 510:	learn: 0.5279339	test: 0.5499558	best: 0.5499558 (510)	total: 953ms	remaining: 912ms
# 520:	learn: 0.5268926	test: 0.5493884	best: 0.5493884 (520)	total: 971ms	remaining: 893ms
# 530:	learn: 0.5258413	test: 0.5488829	best: 0.5488829 (530)	total: 990ms	remaining: 874ms
# 540:	learn: 0.5249430	test: 0.5485494	best: 0.5485494 (540)	total: 1.01s	remaining: 855ms
# 550:	learn: 0.5239909	test: 0.5481596	best: 0.5481596 (550)	total: 1.03s	remaining: 837ms
# 560:	learn: 0.5231161	test: 0.5476239	best: 0.5476239 (560)	total: 1.05s	remaining: 819ms
# 570:	learn: 0.5219695	test: 0.5469648	best: 0.5469648 (570)	total: 1.06s	remaining: 800ms
# 580:	learn: 0.5212668	test: 0.5465351	best: 0.5465351 (580)	total: 1.08s	remaining: 781ms
# 590:	learn: 0.5202942	test: 0.5460599	best: 0.5460599 (590)	total: 1.1s	remaining: 763ms
# 600:	learn: 0.5193586	test: 0.5456929	best: 0.5456929 (600)	total: 1.12s	remaining: 744ms
# 610:	learn: 0.5182212	test: 0.5449618	best: 0.5449618 (610)	total: 1.14s	remaining: 725ms
# 620:	learn: 0.5172979	test: 0.5446094	best: 0.5446094 (620)	total: 1.16s	remaining: 707ms
# 630:	learn: 0.5163288	test: 0.5439870	best: 0.5439870 (630)	total: 1.18s	remaining: 688ms
# 640:	learn: 0.5152215	test: 0.5433219	best: 0.5433219 (640)	total: 1.2s	remaining: 669ms
# 650:	learn: 0.5142663	test: 0.5427230	best: 0.5427230 (650)	total: 1.22s	remaining: 652ms
# 660:	learn: 0.5132823	test: 0.5422585	best: 0.5422585 (660)	total: 1.23s	remaining: 633ms
# 670:	learn: 0.5125460	test: 0.5419823	best: 0.5419823 (670)	total: 1.25s	remaining: 614ms
# 680:	learn: 0.5114590	test: 0.5414747	best: 0.5414747 (680)	total: 1.27s	remaining: 595ms
# 690:	learn: 0.5105888	test: 0.5410429	best: 0.5410429 (690)	total: 1.29s	remaining: 577ms
# 700:	learn: 0.5097647	test: 0.5405710	best: 0.5405710 (700)	total: 1.31s	remaining: 558ms
# 710:	learn: 0.5089534	test: 0.5399591	best: 0.5399591 (710)	total: 1.33s	remaining: 539ms
# 720:	learn: 0.5081832	test: 0.5396911	best: 0.5396815 (719)	total: 1.34s	remaining: 521ms
# 730:	learn: 0.5073269	test: 0.5394665	best: 0.5394665 (730)	total: 1.36s	remaining: 502ms
# 740:	learn: 0.5065260	test: 0.5391498	best: 0.5391453 (739)	total: 1.38s	remaining: 483ms
# 750:	learn: 0.5055858	test: 0.5387137	best: 0.5387137 (750)	total: 1.4s	remaining: 465ms
# 760:	learn: 0.5047593	test: 0.5383623	best: 0.5383623 (760)	total: 1.42s	remaining: 446ms
# 770:	learn: 0.5039998	test: 0.5379980	best: 0.5379980 (770)	total: 1.44s	remaining: 427ms
# 780:	learn: 0.5032874	test: 0.5376961	best: 0.5376961 (780)	total: 1.46s	remaining: 409ms
# 790:	learn: 0.5024732	test: 0.5373775	best: 0.5373775 (790)	total: 1.48s	remaining: 390ms
# 800:	learn: 0.5016435	test: 0.5369943	best: 0.5369943 (800)	total: 1.5s	remaining: 371ms
# 810:	learn: 0.5007124	test: 0.5367968	best: 0.5367968 (810)	total: 1.51s	remaining: 353ms
# 820:	learn: 0.4999685	test: 0.5364976	best: 0.5364976 (820)	total: 1.53s	remaining: 334ms
# 830:	learn: 0.4990690	test: 0.5360539	best: 0.5360539 (830)	total: 1.55s	remaining: 316ms
# 840:	learn: 0.4981149	test: 0.5358104	best: 0.5358104 (840)	total: 1.57s	remaining: 297ms
# 850:	learn: 0.4971182	test: 0.5355583	best: 0.5355557 (848)	total: 1.59s	remaining: 279ms
# 860:	learn: 0.4961583	test: 0.5354142	best: 0.5354142 (860)	total: 1.61s	remaining: 260ms
# 870:	learn: 0.4952196	test: 0.5351869	best: 0.5351495 (869)	total: 1.63s	remaining: 242ms
# 880:	learn: 0.4941127	test: 0.5348557	best: 0.5348557 (880)	total: 1.65s	remaining: 223ms
# 890:	learn: 0.4932893	test: 0.5344557	best: 0.5344493 (889)	total: 1.67s	remaining: 204ms
# 900:	learn: 0.4923075	test: 0.5339678	best: 0.5339678 (900)	total: 1.69s	remaining: 186ms
# 910:	learn: 0.4914812	test: 0.5336065	best: 0.5336065 (910)	total: 1.71s	remaining: 167ms
# 920:	learn: 0.4906382	test: 0.5334454	best: 0.5333896 (916)	total: 1.73s	remaining: 148ms
# 930:	learn: 0.4896661	test: 0.5331496	best: 0.5331496 (930)	total: 1.75s	remaining: 129ms
# 940:	learn: 0.4887260	test: 0.5329079	best: 0.5329079 (940)	total: 1.76s	remaining: 111ms
# 950:	learn: 0.4878005	test: 0.5327169	best: 0.5327111 (949)	total: 1.78s	remaining: 91.9ms
# 960:	learn: 0.4869302	test: 0.5323077	best: 0.5323048 (959)	total: 1.8s	remaining: 73.2ms
# 970:	learn: 0.4860417	test: 0.5320721	best: 0.5320721 (970)	total: 1.82s	remaining: 54.4ms
# 980:	learn: 0.4853217	test: 0.5319275	best: 0.5319275 (980)	total: 1.84s	remaining: 35.6ms
# 990:	learn: 0.4844998	test: 0.5318890	best: 0.5318073 (986)	total: 1.86s	remaining: 16.9ms
# 999:	learn: 0.4836800	test: 0.5317713	best: 0.5317571 (998)	total: 1.88s	remaining: 0us
#
# bestTest = 0.5317570949
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# 0:	learn: 0.6910722	test: 0.6912143	best: 0.6912143 (0)	total: 2.5ms	remaining: 2.5s
# 10:	learn: 0.6726200	test: 0.6747548	best: 0.6747548 (10)	total: 22.2ms	remaining: 2s
# 20:	learn: 0.6576380	test: 0.6612950	best: 0.6612950 (20)	total: 40.2ms	remaining: 1.88s
# 30:	learn: 0.6451274	test: 0.6502531	best: 0.6502531 (30)	total: 58.8ms	remaining: 1.84s
# 40:	learn: 0.6344885	test: 0.6410549	best: 0.6410549 (40)	total: 77ms	remaining: 1.8s
# 50:	learn: 0.6250120	test: 0.6329169	best: 0.6329169 (50)	total: 95.2ms	remaining: 1.77s
# 60:	learn: 0.6172712	test: 0.6259078	best: 0.6259078 (60)	total: 113ms	remaining: 1.75s
# 70:	learn: 0.6108314	test: 0.6204645	best: 0.6204645 (70)	total: 131ms	remaining: 1.72s
# 80:	learn: 0.6054115	test: 0.6159356	best: 0.6159356 (80)	total: 150ms	remaining: 1.7s
# 90:	learn: 0.5999246	test: 0.6116720	best: 0.6116720 (90)	total: 168ms	remaining: 1.68s
# 100:	learn: 0.5953805	test: 0.6080539	best: 0.6080539 (100)	total: 188ms	remaining: 1.67s
# 110:	learn: 0.5910505	test: 0.6044292	best: 0.6044292 (110)	total: 207ms	remaining: 1.66s
# 120:	learn: 0.5873890	test: 0.6015806	best: 0.6015806 (120)	total: 227ms	remaining: 1.65s
# 130:	learn: 0.5841165	test: 0.5993997	best: 0.5993997 (130)	total: 246ms	remaining: 1.63s
# 140:	learn: 0.5810581	test: 0.5972019	best: 0.5972019 (140)	total: 302ms	remaining: 1.84s
# 150:	learn: 0.5783996	test: 0.5953315	best: 0.5953315 (150)	total: 323ms	remaining: 1.81s
# 160:	learn: 0.5760820	test: 0.5935834	best: 0.5935834 (160)	total: 341ms	remaining: 1.78s
# 170:	learn: 0.5737434	test: 0.5919760	best: 0.5919760 (170)	total: 360ms	remaining: 1.74s
# 180:	learn: 0.5716421	test: 0.5905258	best: 0.5905258 (180)	total: 381ms	remaining: 1.73s
# 190:	learn: 0.5697155	test: 0.5890564	best: 0.5890564 (190)	total: 400ms	remaining: 1.69s
# 200:	learn: 0.5677461	test: 0.5877523	best: 0.5877523 (200)	total: 419ms	remaining: 1.67s
# 210:	learn: 0.5660170	test: 0.5865457	best: 0.5865457 (210)	total: 437ms	remaining: 1.64s
# 220:	learn: 0.5642063	test: 0.5852203	best: 0.5852203 (220)	total: 456ms	remaining: 1.61s
# 230:	learn: 0.5626915	test: 0.5841602	best: 0.5841602 (230)	total: 475ms	remaining: 1.58s
# 240:	learn: 0.5607763	test: 0.5831234	best: 0.5831234 (240)	total: 494ms	remaining: 1.55s
# 250:	learn: 0.5588332	test: 0.5819904	best: 0.5819904 (250)	total: 514ms	remaining: 1.53s
# 260:	learn: 0.5574359	test: 0.5811440	best: 0.5811440 (260)	total: 533ms	remaining: 1.51s
# 270:	learn: 0.5558094	test: 0.5801892	best: 0.5801892 (270)	total: 553ms	remaining: 1.49s
# 280:	learn: 0.5542673	test: 0.5793614	best: 0.5793614 (280)	total: 572ms	remaining: 1.46s
# 290:	learn: 0.5528832	test: 0.5786029	best: 0.5786029 (290)	total: 591ms	remaining: 1.44s
# 300:	learn: 0.5515487	test: 0.5775616	best: 0.5775616 (300)	total: 611ms	remaining: 1.42s
# 310:	learn: 0.5500412	test: 0.5765882	best: 0.5765882 (310)	total: 631ms	remaining: 1.4s
# 320:	learn: 0.5488654	test: 0.5759009	best: 0.5759009 (320)	total: 650ms	remaining: 1.37s
# 330:	learn: 0.5476675	test: 0.5752254	best: 0.5752254 (330)	total: 669ms	remaining: 1.35s
# 340:	learn: 0.5461221	test: 0.5745091	best: 0.5745091 (340)	total: 688ms	remaining: 1.33s
# 350:	learn: 0.5447241	test: 0.5736768	best: 0.5736768 (350)	total: 707ms	remaining: 1.31s
# 360:	learn: 0.5433214	test: 0.5729135	best: 0.5729135 (360)	total: 726ms	remaining: 1.28s
# 370:	learn: 0.5422690	test: 0.5721515	best: 0.5721515 (370)	total: 744ms	remaining: 1.26s
# 380:	learn: 0.5408562	test: 0.5714878	best: 0.5714878 (380)	total: 763ms	remaining: 1.24s
# 390:	learn: 0.5396935	test: 0.5707818	best: 0.5707818 (390)	total: 782ms	remaining: 1.22s
# 400:	learn: 0.5384808	test: 0.5701996	best: 0.5701996 (400)	total: 802ms	remaining: 1.2s
# 410:	learn: 0.5373566	test: 0.5695011	best: 0.5695011 (410)	total: 835ms	remaining: 1.2s
# 420:	learn: 0.5365221	test: 0.5691026	best: 0.5691026 (420)	total: 855ms	remaining: 1.18s
# 430:	learn: 0.5353702	test: 0.5685262	best: 0.5685262 (430)	total: 874ms	remaining: 1.15s
# 440:	learn: 0.5340492	test: 0.5679060	best: 0.5679060 (440)	total: 909ms	remaining: 1.15s
# 450:	learn: 0.5329366	test: 0.5674197	best: 0.5674197 (450)	total: 928ms	remaining: 1.13s
# 460:	learn: 0.5318621	test: 0.5668661	best: 0.5668661 (460)	total: 947ms	remaining: 1.11s
# 470:	learn: 0.5309744	test: 0.5664719	best: 0.5664719 (470)	total: 966ms	remaining: 1.08s
# 480:	learn: 0.5300754	test: 0.5660956	best: 0.5660956 (480)	total: 984ms	remaining: 1.06s
# 490:	learn: 0.5288590	test: 0.5656297	best: 0.5656297 (490)	total: 1s	remaining: 1.04s
# 500:	learn: 0.5278497	test: 0.5652075	best: 0.5652075 (500)	total: 1.02s	remaining: 1.02s
# 510:	learn: 0.5267905	test: 0.5647033	best: 0.5647033 (510)	total: 1.04s	remaining: 997ms
# 520:	learn: 0.5257479	test: 0.5641973	best: 0.5641973 (520)	total: 1.06s	remaining: 975ms
# 530:	learn: 0.5246465	test: 0.5635865	best: 0.5635865 (530)	total: 1.08s	remaining: 953ms
# 540:	learn: 0.5237264	test: 0.5630970	best: 0.5630970 (540)	total: 1.1s	remaining: 933ms
# 550:	learn: 0.5227907	test: 0.5626127	best: 0.5626127 (550)	total: 1.12s	remaining: 912ms
# 560:	learn: 0.5217226	test: 0.5622437	best: 0.5622437 (560)	total: 1.14s	remaining: 891ms
# 570:	learn: 0.5207721	test: 0.5619132	best: 0.5619132 (570)	total: 1.16s	remaining: 870ms
# 580:	learn: 0.5195615	test: 0.5612729	best: 0.5612729 (580)	total: 1.18s	remaining: 849ms
# 590:	learn: 0.5184903	test: 0.5608332	best: 0.5608332 (590)	total: 1.2s	remaining: 828ms
# 600:	learn: 0.5177420	test: 0.5606389	best: 0.5606026 (598)	total: 1.22s	remaining: 807ms
# 610:	learn: 0.5167050	test: 0.5602081	best: 0.5602081 (610)	total: 1.23s	remaining: 786ms
# 620:	learn: 0.5159125	test: 0.5598136	best: 0.5597974 (618)	total: 1.25s	remaining: 765ms
# 630:	learn: 0.5149421	test: 0.5595193	best: 0.5595193 (630)	total: 1.27s	remaining: 744ms
# 640:	learn: 0.5136753	test: 0.5591098	best: 0.5590947 (639)	total: 1.29s	remaining: 723ms
# 650:	learn: 0.5127724	test: 0.5587288	best: 0.5587269 (649)	total: 1.31s	remaining: 702ms
# 660:	learn: 0.5119657	test: 0.5584558	best: 0.5584558 (660)	total: 1.33s	remaining: 681ms
# 670:	learn: 0.5110918	test: 0.5583051	best: 0.5583051 (670)	total: 1.35s	remaining: 661ms
# 680:	learn: 0.5102104	test: 0.5579360	best: 0.5579360 (680)	total: 1.37s	remaining: 641ms
# 690:	learn: 0.5093795	test: 0.5576659	best: 0.5576490 (688)	total: 1.39s	remaining: 620ms
# 700:	learn: 0.5084850	test: 0.5572419	best: 0.5572419 (700)	total: 1.41s	remaining: 600ms
# 710:	learn: 0.5076141	test: 0.5570007	best: 0.5569776 (708)	total: 1.43s	remaining: 579ms
# 720:	learn: 0.5069015	test: 0.5568571	best: 0.5568444 (717)	total: 1.44s	remaining: 559ms
# 730:	learn: 0.5060682	test: 0.5565931	best: 0.5565931 (730)	total: 1.46s	remaining: 539ms
# 740:	learn: 0.5052359	test: 0.5562998	best: 0.5562998 (740)	total: 1.48s	remaining: 519ms
# 750:	learn: 0.5042974	test: 0.5559880	best: 0.5559880 (750)	total: 1.5s	remaining: 498ms
# 760:	learn: 0.5035872	test: 0.5557810	best: 0.5557810 (760)	total: 1.52s	remaining: 478ms
# 770:	learn: 0.5026845	test: 0.5553879	best: 0.5553879 (770)	total: 1.54s	remaining: 458ms
# 780:	learn: 0.5018521	test: 0.5552357	best: 0.5552283 (779)	total: 1.56s	remaining: 438ms
# 790:	learn: 0.5010974	test: 0.5550321	best: 0.5550317 (789)	total: 1.58s	remaining: 417ms
# 800:	learn: 0.5001963	test: 0.5548299	best: 0.5548299 (800)	total: 1.6s	remaining: 397ms
# 810:	learn: 0.4993608	test: 0.5544719	best: 0.5544719 (810)	total: 1.62s	remaining: 377ms
# 820:	learn: 0.4985222	test: 0.5541806	best: 0.5541806 (820)	total: 1.64s	remaining: 357ms
# 830:	learn: 0.4976906	test: 0.5539481	best: 0.5539481 (830)	total: 1.66s	remaining: 337ms
# 840:	learn: 0.4966435	test: 0.5536134	best: 0.5536134 (840)	total: 1.68s	remaining: 317ms
# 850:	learn: 0.4957237	test: 0.5532597	best: 0.5532597 (850)	total: 1.7s	remaining: 297ms
# 860:	learn: 0.4950100	test: 0.5530557	best: 0.5530557 (860)	total: 1.72s	remaining: 277ms
# 870:	learn: 0.4939396	test: 0.5528463	best: 0.5528242 (868)	total: 1.73s	remaining: 257ms
# 880:	learn: 0.4929771	test: 0.5526844	best: 0.5526822 (879)	total: 1.75s	remaining: 237ms
# 890:	learn: 0.4919571	test: 0.5525548	best: 0.5525548 (890)	total: 1.77s	remaining: 217ms
# 900:	learn: 0.4911525	test: 0.5524713	best: 0.5524469 (898)	total: 1.79s	remaining: 197ms
# 910:	learn: 0.4900886	test: 0.5522488	best: 0.5521732 (907)	total: 1.81s	remaining: 177ms
# 920:	learn: 0.4892334	test: 0.5519406	best: 0.5519406 (920)	total: 1.83s	remaining: 157ms
# 930:	learn: 0.4883769	test: 0.5518095	best: 0.5517906 (928)	total: 1.85s	remaining: 137ms
# 940:	learn: 0.4875168	test: 0.5517497	best: 0.5517497 (940)	total: 1.87s	remaining: 117ms
# 950:	learn: 0.4866503	test: 0.5517403	best: 0.5516761 (947)	total: 1.89s	remaining: 97.3ms
# 960:	learn: 0.4857980	test: 0.5515738	best: 0.5515193 (959)	total: 1.91s	remaining: 77.4ms
# 970:	learn: 0.4850348	test: 0.5515165	best: 0.5515163 (969)	total: 1.93s	remaining: 57.5ms
# 980:	learn: 0.4842612	test: 0.5513672	best: 0.5513403 (978)	total: 1.94s	remaining: 37.7ms
# 990:	learn: 0.4836277	test: 0.5512189	best: 0.5512137 (989)	total: 1.96s	remaining: 17.8ms
# 999:	learn: 0.4830423	test: 0.5509871	best: 0.5509871 (999)	total: 1.98s	remaining: 0us
#
# bestTest = 0.5509870625
# bestIteration = 999
# 0:	learn: 0.6910231	test: 0.6911028	best: 0.6911028 (0)	total: 15.9ms	remaining: 15.9s
# 10:	learn: 0.6722935	test: 0.6735979	best: 0.6735979 (10)	total: 36.6ms	remaining: 3.29s
# 20:	learn: 0.6574175	test: 0.6595018	best: 0.6595018 (20)	total: 57.7ms	remaining: 2.69s
# 30:	learn: 0.6444161	test: 0.6474868	best: 0.6474868 (30)	total: 78.8ms	remaining: 2.46s
# 40:	learn: 0.6341139	test: 0.6378273	best: 0.6378273 (40)	total: 99.4ms	remaining: 2.33s
# 50:	learn: 0.6249112	test: 0.6293041	best: 0.6293041 (50)	total: 121ms	remaining: 2.25s
# 60:	learn: 0.6169669	test: 0.6221486	best: 0.6221486 (60)	total: 142ms	remaining: 2.19s
# 70:	learn: 0.6104973	test: 0.6164491	best: 0.6164491 (70)	total: 163ms	remaining: 2.13s
# 80:	learn: 0.6042321	test: 0.6109589	best: 0.6109589 (80)	total: 184ms	remaining: 2.09s
# 90:	learn: 0.5989807	test: 0.6063694	best: 0.6063694 (90)	total: 207ms	remaining: 2.07s
# 100:	learn: 0.5942414	test: 0.6020927	best: 0.6020927 (100)	total: 229ms	remaining: 2.04s
# 110:	learn: 0.5901037	test: 0.5985899	best: 0.5985899 (110)	total: 251ms	remaining: 2.01s
# 120:	learn: 0.5863847	test: 0.5952192	best: 0.5952192 (120)	total: 272ms	remaining: 1.98s
# 130:	learn: 0.5832866	test: 0.5926219	best: 0.5926219 (130)	total: 295ms	remaining: 1.96s
# 140:	learn: 0.5803365	test: 0.5900907	best: 0.5900907 (140)	total: 318ms	remaining: 1.94s
# 150:	learn: 0.5778044	test: 0.5880574	best: 0.5880574 (150)	total: 340ms	remaining: 1.91s
# 160:	learn: 0.5755461	test: 0.5862513	best: 0.5862513 (160)	total: 361ms	remaining: 1.88s
# 170:	learn: 0.5733606	test: 0.5845378	best: 0.5845378 (170)	total: 384ms	remaining: 1.86s
# 180:	learn: 0.5711780	test: 0.5827788	best: 0.5827788 (180)	total: 405ms	remaining: 1.83s
# 190:	learn: 0.5691500	test: 0.5811877	best: 0.5811877 (190)	total: 426ms	remaining: 1.81s
# 200:	learn: 0.5670779	test: 0.5795617	best: 0.5795617 (200)	total: 448ms	remaining: 1.78s
# 210:	learn: 0.5652514	test: 0.5782154	best: 0.5782154 (210)	total: 470ms	remaining: 1.76s
# 220:	learn: 0.5634824	test: 0.5767858	best: 0.5767858 (220)	total: 491ms	remaining: 1.73s
# 230:	learn: 0.5619204	test: 0.5756608	best: 0.5756608 (230)	total: 512ms	remaining: 1.7s
# 240:	learn: 0.5604343	test: 0.5745593	best: 0.5745593 (240)	total: 534ms	remaining: 1.68s
# 250:	learn: 0.5588319	test: 0.5735215	best: 0.5735215 (250)	total: 556ms	remaining: 1.66s
# 260:	learn: 0.5572640	test: 0.5721881	best: 0.5721881 (260)	total: 578ms	remaining: 1.64s
# 270:	learn: 0.5558151	test: 0.5710105	best: 0.5710105 (270)	total: 600ms	remaining: 1.61s
# 280:	learn: 0.5543743	test: 0.5700484	best: 0.5700484 (280)	total: 622ms	remaining: 1.59s
# 290:	learn: 0.5530872	test: 0.5688894	best: 0.5688894 (290)	total: 644ms	remaining: 1.57s
# 300:	learn: 0.5517392	test: 0.5679971	best: 0.5679971 (300)	total: 665ms	remaining: 1.54s
# 310:	learn: 0.5501511	test: 0.5667240	best: 0.5667240 (310)	total: 686ms	remaining: 1.52s
# 320:	learn: 0.5487102	test: 0.5656471	best: 0.5656471 (320)	total: 708ms	remaining: 1.5s
# 330:	learn: 0.5473331	test: 0.5648718	best: 0.5648718 (330)	total: 730ms	remaining: 1.47s
# 340:	learn: 0.5459393	test: 0.5639205	best: 0.5639205 (340)	total: 751ms	remaining: 1.45s
# 350:	learn: 0.5447660	test: 0.5632325	best: 0.5632325 (350)	total: 772ms	remaining: 1.43s
# 360:	learn: 0.5437126	test: 0.5623800	best: 0.5623800 (360)	total: 794ms	remaining: 1.41s
# 370:	learn: 0.5426201	test: 0.5618294	best: 0.5618294 (370)	total: 816ms	remaining: 1.38s
# 380:	learn: 0.5415798	test: 0.5611384	best: 0.5611384 (380)	total: 838ms	remaining: 1.36s
# 390:	learn: 0.5403881	test: 0.5604295	best: 0.5604295 (390)	total: 860ms	remaining: 1.34s
# 400:	learn: 0.5394293	test: 0.5597770	best: 0.5597770 (400)	total: 880ms	remaining: 1.31s
# 410:	learn: 0.5382316	test: 0.5589238	best: 0.5589238 (410)	total: 903ms	remaining: 1.29s
# 420:	learn: 0.5372091	test: 0.5581534	best: 0.5581534 (420)	total: 925ms	remaining: 1.27s
# 430:	learn: 0.5361598	test: 0.5574379	best: 0.5574379 (430)	total: 947ms	remaining: 1.25s
# 440:	learn: 0.5349367	test: 0.5567867	best: 0.5567867 (440)	total: 970ms	remaining: 1.23s
# 450:	learn: 0.5338928	test: 0.5561284	best: 0.5561284 (450)	total: 993ms	remaining: 1.21s
# 460:	learn: 0.5327074	test: 0.5553294	best: 0.5553294 (460)	total: 1.01s	remaining: 1.19s
# 470:	learn: 0.5315695	test: 0.5547869	best: 0.5547869 (470)	total: 1.04s	remaining: 1.17s
# 480:	learn: 0.5305775	test: 0.5541095	best: 0.5541095 (480)	total: 1.06s	remaining: 1.15s
# 490:	learn: 0.5294136	test: 0.5534074	best: 0.5534074 (490)	total: 1.08s	remaining: 1.12s
# 500:	learn: 0.5285372	test: 0.5528970	best: 0.5528970 (500)	total: 1.11s	remaining: 1.1s
# 510:	learn: 0.5274387	test: 0.5523858	best: 0.5523858 (510)	total: 1.13s	remaining: 1.08s
# 520:	learn: 0.5264914	test: 0.5518097	best: 0.5518097 (520)	total: 1.15s	remaining: 1.06s
# 530:	learn: 0.5255339	test: 0.5510179	best: 0.5510179 (530)	total: 1.17s	remaining: 1.03s
# 540:	learn: 0.5244382	test: 0.5503646	best: 0.5503646 (540)	total: 1.19s	remaining: 1.01s
# 550:	learn: 0.5232877	test: 0.5498650	best: 0.5498650 (550)	total: 1.21s	remaining: 990ms
# 560:	learn: 0.5223014	test: 0.5493228	best: 0.5493228 (560)	total: 1.24s	remaining: 969ms
# 570:	learn: 0.5213593	test: 0.5488632	best: 0.5488632 (570)	total: 1.26s	remaining: 948ms
# 580:	learn: 0.5202878	test: 0.5482268	best: 0.5482268 (580)	total: 1.28s	remaining: 926ms
# 590:	learn: 0.5193493	test: 0.5477377	best: 0.5477377 (590)	total: 1.31s	remaining: 905ms
# 600:	learn: 0.5182986	test: 0.5471007	best: 0.5471007 (600)	total: 1.33s	remaining: 883ms
# 610:	learn: 0.5172835	test: 0.5465348	best: 0.5465348 (610)	total: 1.35s	remaining: 861ms
# 620:	learn: 0.5164860	test: 0.5460165	best: 0.5460165 (620)	total: 1.37s	remaining: 839ms
# 630:	learn: 0.5156094	test: 0.5455620	best: 0.5455564 (629)	total: 1.4s	remaining: 817ms
# 640:	learn: 0.5145467	test: 0.5449959	best: 0.5449959 (640)	total: 1.42s	remaining: 795ms
# 650:	learn: 0.5137852	test: 0.5444632	best: 0.5444632 (650)	total: 1.44s	remaining: 773ms
# 660:	learn: 0.5129519	test: 0.5440330	best: 0.5440330 (660)	total: 1.46s	remaining: 751ms
# 670:	learn: 0.5120475	test: 0.5434167	best: 0.5434167 (670)	total: 1.49s	remaining: 729ms
# 680:	learn: 0.5112170	test: 0.5429922	best: 0.5429922 (680)	total: 1.51s	remaining: 707ms
# 690:	learn: 0.5103497	test: 0.5425642	best: 0.5425642 (690)	total: 1.53s	remaining: 686ms
# 700:	learn: 0.5093314	test: 0.5421069	best: 0.5421069 (700)	total: 1.56s	remaining: 664ms
# 710:	learn: 0.5083970	test: 0.5417737	best: 0.5417737 (710)	total: 1.58s	remaining: 642ms
# 720:	learn: 0.5077164	test: 0.5414146	best: 0.5414146 (720)	total: 1.6s	remaining: 620ms
# 730:	learn: 0.5069548	test: 0.5410002	best: 0.5410002 (730)	total: 1.62s	remaining: 598ms
# 740:	learn: 0.5060996	test: 0.5407559	best: 0.5407559 (740)	total: 1.65s	remaining: 576ms
# 750:	learn: 0.5050450	test: 0.5403182	best: 0.5403182 (750)	total: 1.67s	remaining: 554ms
# 760:	learn: 0.5043030	test: 0.5400280	best: 0.5400137 (759)	total: 1.69s	remaining: 531ms
# 770:	learn: 0.5033117	test: 0.5398086	best: 0.5398025 (769)	total: 1.71s	remaining: 509ms
# 780:	learn: 0.5024938	test: 0.5394623	best: 0.5394623 (780)	total: 1.73s	remaining: 486ms
# 790:	learn: 0.5017712	test: 0.5391651	best: 0.5391651 (790)	total: 1.76s	remaining: 464ms
# 800:	learn: 0.5008775	test: 0.5388355	best: 0.5388355 (800)	total: 1.78s	remaining: 442ms
# 810:	learn: 0.4999553	test: 0.5385670	best: 0.5385670 (810)	total: 1.8s	remaining: 420ms
# 820:	learn: 0.4990325	test: 0.5383379	best: 0.5383328 (819)	total: 1.82s	remaining: 398ms
# 830:	learn: 0.4981729	test: 0.5381294	best: 0.5381294 (830)	total: 1.85s	remaining: 376ms
# 840:	learn: 0.4972673	test: 0.5377903	best: 0.5377903 (840)	total: 1.87s	remaining: 354ms
# 850:	learn: 0.4964842	test: 0.5375347	best: 0.5375347 (850)	total: 1.89s	remaining: 332ms
# 860:	learn: 0.4955677	test: 0.5370547	best: 0.5370547 (860)	total: 1.92s	remaining: 310ms
# 870:	learn: 0.4948264	test: 0.5367848	best: 0.5367848 (870)	total: 1.94s	remaining: 287ms
# 880:	learn: 0.4940111	test: 0.5365494	best: 0.5365494 (880)	total: 1.96s	remaining: 265ms
# 890:	learn: 0.4931361	test: 0.5362718	best: 0.5362718 (890)	total: 1.99s	remaining: 243ms
# 900:	learn: 0.4923135	test: 0.5360997	best: 0.5360997 (900)	total: 2.01s	remaining: 221ms
# 910:	learn: 0.4914771	test: 0.5359472	best: 0.5359472 (910)	total: 2.03s	remaining: 198ms
# 920:	learn: 0.4907506	test: 0.5358422	best: 0.5358422 (920)	total: 2.05s	remaining: 176ms
# 930:	learn: 0.4898239	test: 0.5357094	best: 0.5356952 (929)	total: 2.07s	remaining: 154ms
# 940:	learn: 0.4890707	test: 0.5354983	best: 0.5354667 (937)	total: 2.09s	remaining: 131ms
# 950:	learn: 0.4881661	test: 0.5353416	best: 0.5353416 (950)	total: 2.12s	remaining: 109ms
# 960:	learn: 0.4874416	test: 0.5352261	best: 0.5352261 (960)	total: 2.14s	remaining: 86.9ms
# 970:	learn: 0.4866404	test: 0.5350452	best: 0.5350306 (967)	total: 2.16s	remaining: 64.6ms
# 980:	learn: 0.4859537	test: 0.5349206	best: 0.5349206 (980)	total: 2.19s	remaining: 42.4ms
# 990:	learn: 0.4853306	test: 0.5346165	best: 0.5346165 (990)	total: 2.21s	remaining: 20.1ms
# 999:	learn: 0.4847142	test: 0.5344124	best: 0.5344124 (999)	total: 2.23s	remaining: 0us
#
# bestTest = 0.5344124303
# bestIteration = 999
# CV Score:
#   Precision Score = 0.023772
#   Recall Score = 0.804355
#   F1 Score = 0.046174
#   Accuracy Score = 0.627659
#   no_Leq = 55.975535
#   y_Leq = 55.937235
#   pred_Leq = 54.746749
