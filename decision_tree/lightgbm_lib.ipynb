# %%
import lightgbm as lgb
import warnings
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score
from sklearn.exceptions import UndefinedMetricWarning
from sklearn.model_selection import KFold
import pandas as pd
import os
import numpy as np
import support 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def under_sampling(x):
    import warnings
    import pandas as pd
    import os
    warnings.simplefilter('ignore', pd.core.common.SettingWithCopyWarning)
    df = x
    x_majority=df.loc[df.iloc[:,-1]==0]
    x_minority=df.loc[df.iloc[:,-1]==1]
    from sklearn.cluster import KMeans
    km = KMeans(random_state=1, n_clusters=10)
    km.fit(x_majority.iloc[:, :-1])
    x_majority['Cluster'] = km.predict(x_majority.iloc[:, :-1])
    ratio = x_majority['Cluster'].value_counts() / x_majority.shape[0]
    n_sample_ary = (ratio * x_minority.shape[0]).sort_index().astype('int64')
    df_Xs=[]
    for i, n_sample in enumerate(n_sample_ary):
        #重複を許すか許さないかで変わるのか？
        df_Xs.append(x_majority[x_majority['Cluster']==i].sample(n=n_sample, replace=True))

    df_Xs.append(x_minority)
    x=pd.concat(df_Xs, sort=True)
    x=x.drop('Cluster', axis=1)
    
    return x

def calc_avg(x, y):
    import pandas as pd
    import os
    df_x=pd.DataFrame(x)
    df_y=pd.DataFrame(y)
    df_x_raw=df_x[(df_x.shape[1]-1)/2]
    raw_df=pd.concat([df_x_raw, df_y], axis=1)
    raw_df.columns=range(raw_df.shape[1])
    df_ex=raw_df.loc[raw_df[1]==0]
    N=len(df_ex)
    Leq=10*np.log10(np.sum(np.power(10, df_ex[0]/10)))-10*np.log10(N)
    return Leq

def calc_avg2(x, y):
    import pandas as pd
    import os
    df_x=pd.DataFrame(x)
    df_y=pd.DataFrame(y)
    df_x_raw=df_x[(df_x.shape[1]-1)/2]
    raw_df=pd.concat([df_x_raw, df_y], axis=1)
    raw_df.columns=range(raw_df.shape[1])
    df_ex=raw_df
    N=len(df_ex)
    Leq=10*np.log10(np.sum(np.power(10, df_ex[0]/10)))-10*np.log10(N)
    return Leq

df = pd.read_csv( os.path.join('dataset', 'learning_data_431975.csv'), header=None  )
x = df[ df.columns[ :-1 ] ]
y=  df[ df.columns[ -1 ] ]
kf = KFold( n_splits=3, random_state=1, shuffle=True )
pr=[]
re=[]
f1 = []
ac = []
y_Leq=[]
pred_Leq=[]
no_Leq=[]
n = []

for train_index, test_index in kf.split( x ):
    x_train, x_test = x.loc[train_index, :].values, x.loc[test_index, :].values
    y_train, y_test = y.loc[train_index].values, y.loc[test_index].values

    # 学習データだけダウンサンプリング
    y_data=y_train[:, np.newaxis]
    data=np.concatenate([x_train, y_data], 1)
    train_df=pd.DataFrame(data)
    train_us=under_sampling(train_df)
    index = train_us.index.tolist()
    x_train=x_train[index]
    y_train=y_train[index]
    
    # アーリーストッピング(学習の打ち切り)するために、学習中のバリデーション用の検証データを作成
    # (学習データをさらに ’学習データ’と ’検証データ’ に分割)
    x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=True)
    
    # XGBoost用にデータを加工
    dtrain = lgb.Dataset(x_train, label=y_train)
    dvalid = lgb.Dataset(x_valid, label=y_valid, reference=dtrain) # 学習中のバリデーション用の検証データ
    
    params = {'objective':'binary',
              'metric': 'binary_logloss', # 学習中のバリデーションに使う評価指標
              'random_state':1,
              'learning_rate':0.01,  
             }
    num_round = 1000
    evals_result={}
    
    model = lgb.train(params, dtrain, num_round, verbose_eval=10, 
                      valid_sets=[dtrain,dvalid], valid_names=['train', 'valid'], 
                      evals_result=evals_result, early_stopping_rounds=10)
    
    
    # 検証結果のうち最も結果が良かった木の数で予測
    y_pred_proba = model.predict(x_test,   num_iteration=model.best_iteration)
    z = np.where(y_pred_proba > 0.5, 1, 0)
    
    pr.append( precision_score( y_test, z ) )
    re.append( recall_score( y_test, z) )
    f1.append( f1_score( y_test, z ) )
    ac.append( accuracy_score( y_test, z ) )
    n.append( len( x_test ) / len( x ) )

    #等価騒音レベル計算
    no_Leq.append(calc_avg2(x_test, y_test))
    y_Leq.append(calc_avg(x_test, y_test))
    pred_Leq.append(calc_avg(x_test, z))
    
    # 学習の課程を折れ線グラフとしてプロットする
    train_metric = evals_result['train']['binary_logloss']
    plt.plot(train_metric, label='train logloss')
    eval_metric = evals_result['valid']['binary_logloss']
    plt.plot(eval_metric, label='valid logloss')
    plt.grid()
    plt.legend()
    plt.xlabel('rounds')
    plt.ylabel('logloss')
    plt.show()

    
print( 'CV Score:' )
print( '  Precision Score = %f'%( np.average( pr, weights=n ) ) )
print( '  Recall Score = %f'%( np.average( re, weights=n ) ) )
print( '  F1 Score = %f'%( np.average( f1, weights=n ) ) )
print( '  Accuracy Score = %f'%( np.average( ac, weights=n ) ) )
print( '  no_Leq = %f'%( np.average( no_Leq, weights=n ) ) )
print( '  y_Leq = %f'%( np.average( y_Leq, weights=n ) ) )
print( '  pred_Leq = %f'%( np.average( pred_Leq, weights=n ) ) )
# Out:
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2533, number of negative: 2578
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000691 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2802
# [LightGBM] [Info] Number of data points in the train set: 5111, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495598 -> initscore=-0.017610
# [LightGBM] [Info] Start training from score -0.017610
# Training until validation scores don't improve for 10 rounds
# [10]	train's binary_logloss: 0.670905	valid's binary_logloss: 0.672125
# [20]	train's binary_logloss: 0.651742	valid's binary_logloss: 0.654291
# [30]	train's binary_logloss: 0.635239	valid's binary_logloss: 0.639325
# [40]	train's binary_logloss: 0.621456	valid's binary_logloss: 0.627312
# [50]	train's binary_logloss: 0.609029	valid's binary_logloss: 0.616472
# [60]	train's binary_logloss: 0.598157	valid's binary_logloss: 0.606935
# [70]	train's binary_logloss: 0.588324	valid's binary_logloss: 0.598498
# [80]	train's binary_logloss: 0.57933	valid's binary_logloss: 0.590848
# [90]	train's binary_logloss: 0.571113	valid's binary_logloss: 0.584619
# [100]	train's binary_logloss: 0.564139	valid's binary_logloss: 0.579679
# [110]	train's binary_logloss: 0.557889	valid's binary_logloss: 0.574856
# [120]	train's binary_logloss: 0.552369	valid's binary_logloss: 0.570918
# [130]	train's binary_logloss: 0.546713	valid's binary_logloss: 0.567127
# [140]	train's binary_logloss: 0.541699	valid's binary_logloss: 0.563748
# [150]	train's binary_logloss: 0.53708	valid's binary_logloss: 0.561081
# [160]	train's binary_logloss: 0.533156	valid's binary_logloss: 0.558777
# [170]	train's binary_logloss: 0.529376	valid's binary_logloss: 0.556673
# [180]	train's binary_logloss: 0.526117	valid's binary_logloss: 0.555001
# [190]	train's binary_logloss: 0.523167	valid's binary_logloss: 0.553495
# [200]	train's binary_logloss: 0.520257	valid's binary_logloss: 0.55174
# [210]	train's binary_logloss: 0.517474	valid's binary_logloss: 0.550403
# [220]	train's binary_logloss: 0.514939	valid's binary_logloss: 0.549212
# [230]	train's binary_logloss: 0.512102	valid's binary_logloss: 0.547769
# [240]	train's binary_logloss: 0.509733	valid's binary_logloss: 0.546805
# [250]	train's binary_logloss: 0.507175	valid's binary_logloss: 0.545891
# [260]	train's binary_logloss: 0.504291	valid's binary_logloss: 0.544817
# [270]	train's binary_logloss: 0.502099	valid's binary_logloss: 0.54437
# [280]	train's binary_logloss: 0.499013	valid's binary_logloss: 0.543176
# [290]	train's binary_logloss: 0.495056	valid's binary_logloss: 0.541545
# [300]	train's binary_logloss: 0.49069	valid's binary_logloss: 0.539459
# [310]	train's binary_logloss: 0.486875	valid's binary_logloss: 0.537406
# [320]	train's binary_logloss: 0.483584	valid's binary_logloss: 0.536012
# [330]	train's binary_logloss: 0.48132	valid's binary_logloss: 0.535644
# [340]	train's binary_logloss: 0.47768	valid's binary_logloss: 0.534333
# [350]	train's binary_logloss: 0.474773	valid's binary_logloss: 0.533442
# [360]	train's binary_logloss: 0.471513	valid's binary_logloss: 0.532341
# [370]	train's binary_logloss: 0.468482	valid's binary_logloss: 0.531406
# [380]	train's binary_logloss: 0.465288	valid's binary_logloss: 0.530252
# [390]	train's binary_logloss: 0.462598	valid's binary_logloss: 0.529536
# [400]	train's binary_logloss: 0.460114	valid's binary_logloss: 0.528875
# [410]	train's binary_logloss: 0.457635	valid's binary_logloss: 0.528217
# [420]	train's binary_logloss: 0.455334	valid's binary_logloss: 0.527337
# [430]	train's binary_logloss: 0.453139	valid's binary_logloss: 0.526794
# [440]	train's binary_logloss: 0.450896	valid's binary_logloss: 0.526433
# [450]	train's binary_logloss: 0.448473	valid's binary_logloss: 0.525767
# [460]	train's binary_logloss: 0.446478	valid's binary_logloss: 0.525742
# [470]	train's binary_logloss: 0.444668	valid's binary_logloss: 0.525469
# [480]	train's binary_logloss: 0.442728	valid's binary_logloss: 0.525137
# [490]	train's binary_logloss: 0.440967	valid's binary_logloss: 0.524908
# [500]	train's binary_logloss: 0.43944	valid's binary_logloss: 0.525039
# Early stopping, best iteration is:
# [492]	train's binary_logloss: 0.440635	valid's binary_logloss: 0.524844
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2603, number of negative: 2589
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2799
# [LightGBM] [Info] Number of data points in the train set: 5192, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501348 -> initscore=0.005393
# [LightGBM] [Info] Start training from score 0.005393
# Training until validation scores don't improve for 10 rounds
# [10]	train's binary_logloss: 0.66892	valid's binary_logloss: 0.674137
# [20]	train's binary_logloss: 0.648317	valid's binary_logloss: 0.658093
# [30]	train's binary_logloss: 0.630592	valid's binary_logloss: 0.644476
# [40]	train's binary_logloss: 0.615395	valid's binary_logloss: 0.632753
# [50]	train's binary_logloss: 0.601624	valid's binary_logloss: 0.62227
# [60]	train's binary_logloss: 0.589555	valid's binary_logloss: 0.613477
# [70]	train's binary_logloss: 0.578945	valid's binary_logloss: 0.605715
# [80]	train's binary_logloss: 0.569513	valid's binary_logloss: 0.599332
# [90]	train's binary_logloss: 0.561002	valid's binary_logloss: 0.593615
# [100]	train's binary_logloss: 0.553142	valid's binary_logloss: 0.588379
# [110]	train's binary_logloss: 0.545959	valid's binary_logloss: 0.584055
# [120]	train's binary_logloss: 0.53941	valid's binary_logloss: 0.580275
# [130]	train's binary_logloss: 0.533213	valid's binary_logloss: 0.577274
# [140]	train's binary_logloss: 0.527863	valid's binary_logloss: 0.574909
# [150]	train's binary_logloss: 0.523398	valid's binary_logloss: 0.573183
# [160]	train's binary_logloss: 0.518892	valid's binary_logloss: 0.571196
# [170]	train's binary_logloss: 0.514927	valid's binary_logloss: 0.569711
# [180]	train's binary_logloss: 0.511309	valid's binary_logloss: 0.568385
# [190]	train's binary_logloss: 0.507649	valid's binary_logloss: 0.567185
# [200]	train's binary_logloss: 0.504248	valid's binary_logloss: 0.566114
# [210]	train's binary_logloss: 0.50125	valid's binary_logloss: 0.565403
# [220]	train's binary_logloss: 0.498486	valid's binary_logloss: 0.564844
# [230]	train's binary_logloss: 0.495757	valid's binary_logloss: 0.564136
# [240]	train's binary_logloss: 0.49321	valid's binary_logloss: 0.563779
# [250]	train's binary_logloss: 0.490626	valid's binary_logloss: 0.563371
# [260]	train's binary_logloss: 0.488211	valid's binary_logloss: 0.563346
# Early stopping, best iteration is:
# [253]	train's binary_logloss: 0.489805	valid's binary_logloss: 0.563256
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Arakawa\anaconda3\lib\site-packages\lightgbm\engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2555, number of negative: 2576
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000353 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2802
# [LightGBM] [Info] Number of data points in the train set: 5131, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497954 -> initscore=-0.008186
# [LightGBM] [Info] Start training from score -0.008186
# Training until validation scores don't improve for 10 rounds
# [10]	train's binary_logloss: 0.669053	valid's binary_logloss: 0.673166
# [20]	train's binary_logloss: 0.648861	valid's binary_logloss: 0.656507
# [30]	train's binary_logloss: 0.631847	valid's binary_logloss: 0.642728
# [40]	train's binary_logloss: 0.617203	valid's binary_logloss: 0.631149
# [50]	train's binary_logloss: 0.604322	valid's binary_logloss: 0.621489
# [60]	train's binary_logloss: 0.592735	valid's binary_logloss: 0.61272
# [70]	train's binary_logloss: 0.582478	valid's binary_logloss: 0.604833
# [80]	train's binary_logloss: 0.573196	valid's binary_logloss: 0.59828
# [90]	train's binary_logloss: 0.564889	valid's binary_logloss: 0.592703
# [100]	train's binary_logloss: 0.557469	valid's binary_logloss: 0.587722
# [110]	train's binary_logloss: 0.55071	valid's binary_logloss: 0.583387
# [120]	train's binary_logloss: 0.544458	valid's binary_logloss: 0.579329
# [130]	train's binary_logloss: 0.538839	valid's binary_logloss: 0.575775
# [140]	train's binary_logloss: 0.533864	valid's binary_logloss: 0.572671
# [150]	train's binary_logloss: 0.529328	valid's binary_logloss: 0.570059
# [160]	train's binary_logloss: 0.525162	valid's binary_logloss: 0.567829
# [170]	train's binary_logloss: 0.520409	valid's binary_logloss: 0.565257
# [180]	train's binary_logloss: 0.516471	valid's binary_logloss: 0.563222
# [190]	train's binary_logloss: 0.512882	valid's binary_logloss: 0.561694
# [200]	train's binary_logloss: 0.509491	valid's binary_logloss: 0.560311
# [210]	train's binary_logloss: 0.506378	valid's binary_logloss: 0.559464
# [220]	train's binary_logloss: 0.5036	valid's binary_logloss: 0.558781
# [230]	train's binary_logloss: 0.500822	valid's binary_logloss: 0.558162
# [240]	train's binary_logloss: 0.498074	valid's binary_logloss: 0.557669
# [250]	train's binary_logloss: 0.495577	valid's binary_logloss: 0.557207
# [260]	train's binary_logloss: 0.49311	valid's binary_logloss: 0.556655
# [270]	train's binary_logloss: 0.4908	valid's binary_logloss: 0.556256
# [280]	train's binary_logloss: 0.488679	valid's binary_logloss: 0.555705
# [290]	train's binary_logloss: 0.486538	valid's binary_logloss: 0.555398
# [300]	train's binary_logloss: 0.484347	valid's binary_logloss: 0.555069
# [310]	train's binary_logloss: 0.482208	valid's binary_logloss: 0.554727
# [320]	train's binary_logloss: 0.478498	valid's binary_logloss: 0.553199
# [330]	train's binary_logloss: 0.475543	valid's binary_logloss: 0.55198
# [340]	train's binary_logloss: 0.472714	valid's binary_logloss: 0.551137
# [350]	train's binary_logloss: 0.470088	valid's binary_logloss: 0.550507
# [360]	train's binary_logloss: 0.467955	valid's binary_logloss: 0.550149
# [370]	train's binary_logloss: 0.465556	valid's binary_logloss: 0.549539
# [380]	train's binary_logloss: 0.46318	valid's binary_logloss: 0.548618
# [390]	train's binary_logloss: 0.460729	valid's binary_logloss: 0.547883
# [400]	train's binary_logloss: 0.458532	valid's binary_logloss: 0.547309
# [410]	train's binary_logloss: 0.456611	valid's binary_logloss: 0.547216
# [420]	train's binary_logloss: 0.454761	valid's binary_logloss: 0.54693
# [430]	train's binary_logloss: 0.452962	valid's binary_logloss: 0.546825
# [440]	train's binary_logloss: 0.450998	valid's binary_logloss: 0.546493
# [450]	train's binary_logloss: 0.448979	valid's binary_logloss: 0.546079
# [460]	train's binary_logloss: 0.447055	valid's binary_logloss: 0.545743
# [470]	train's binary_logloss: 0.445344	valid's binary_logloss: 0.545632
# [480]	train's binary_logloss: 0.443865	valid's binary_logloss: 0.545446
# [490]	train's binary_logloss: 0.442227	valid's binary_logloss: 0.545399
# [500]	train's binary_logloss: 0.440449	valid's binary_logloss: 0.545174
# [510]	train's binary_logloss: 0.438834	valid's binary_logloss: 0.545054
# Early stopping, best iteration is:
# [503]	train's binary_logloss: 0.439924	valid's binary_logloss: 0.545021
# CV Score:
#   Precision Score = 0.022581
#   Recall Score = 0.796163
#   F1 Score = 0.043912
#   Accuracy Score = 0.611834
#   no_Leq = 55.975535
#   y_Leq = 55.937235
#   pred_Leq = 54.612601
